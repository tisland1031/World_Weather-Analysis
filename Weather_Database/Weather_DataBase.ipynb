# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bbc4a8462878514ff81e8c3a45744367

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Create a list for holding the cities.
cities=[]

#Identify the nearest city for each latitude and longitude combinations
for lat_lngs in lat_lngs:
    city = citipy.nearest_city(lat_lngs[0], lat_lngs[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san policarpo
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | hot springs
# Processing Record 5 of Set 1 | pochutla
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | aksarka
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | padang
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | krasnoselkup
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | atar
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | cuamba
# Processing Record 22 of Set 1 | poum
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | eston
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | namibe
# Processing Record 28 of Set 1 | thanh hoa
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | pandamatenga
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | luderitz
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | thongwa
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | tura
# City not found. Skipping...
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | lucea
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | beidao
# Processing Record 48 of Set 1 | san luis
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | murgab
# Processing Record 2 of Set 2 | bathsheba
# Processing Record 3 of Set 2 | mogadishu
# Processing Record 4 of Set 2 | salinas
# Processing Record 5 of Set 2 | tias
# Processing Record 6 of Set 2 | nam tha
# City not found. Skipping...
# Processing Record 7 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | bonavista
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | kumano
# Processing Record 14 of Set 2 | yinchuan
# Processing Record 15 of Set 2 | saint-francois
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | canutama
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 2 | alta floresta
# Processing Record 24 of Set 2 | evensk
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | san patricio
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | yetholm
# City not found. Skipping...
# Processing Record 29 of Set 2 | kaeo
# Processing Record 30 of Set 2 | kaohsiung
# Processing Record 31 of Set 2 | sao filipe
# Processing Record 32 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | viedma
# Processing Record 35 of Set 2 | shingu
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | huilong
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | aljezur
# Processing Record 40 of Set 2 | faya
# Processing Record 41 of Set 2 | shizunai
# Processing Record 42 of Set 2 | kimbe
# Processing Record 43 of Set 2 | brandfort
# Processing Record 44 of Set 2 | jatara
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | gazojak
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | flinders
# Processing Record 1 of Set 3 | kasongo-lunda
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | maniitsoq
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | portland
# Processing Record 7 of Set 3 | aguada de pasajeros
# Processing Record 8 of Set 3 | coihaique
# Processing Record 9 of Set 3 | maceio
# Processing Record 10 of Set 3 | sao lourenco do sul
# Processing Record 11 of Set 3 | northam
# Processing Record 12 of Set 3 | makakilo city
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | rikitea
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | bowen
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | jurbarkas
# Processing Record 19 of Set 3 | verkhnyaya inta
# Processing Record 20 of Set 3 | bati
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | minab
# Processing Record 23 of Set 3 | ignacio zaragoza
# Processing Record 24 of Set 3 | abancay
# Processing Record 25 of Set 3 | wuning
# Processing Record 26 of Set 3 | pangkalanbuun
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 3 | phek
# Processing Record 31 of Set 3 | avera
# Processing Record 32 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 3 | te anau
# Processing Record 34 of Set 3 | ixtapa
# Processing Record 35 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | port alfred
# Processing Record 38 of Set 3 | luzhou
# Processing Record 39 of Set 3 | nabire
# Processing Record 40 of Set 3 | klaksvik
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | isiro
# Processing Record 43 of Set 3 | ecija
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | beni mazar
# Processing Record 46 of Set 3 | eastlake
# Processing Record 47 of Set 3 | constitucion
# Processing Record 48 of Set 3 | dongtai
# Processing Record 49 of Set 3 | quatre cocos
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | thinadhoo
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | lagoa
# Processing Record 4 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 4 | cayenne
# Processing Record 6 of Set 4 | puerto ayora
# Processing Record 7 of Set 4 | blenheim
# Processing Record 8 of Set 4 | mountain home
# Processing Record 9 of Set 4 | kamenka
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | santa cruz del sur
# Processing Record 12 of Set 4 | nome
# Processing Record 13 of Set 4 | boditi
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | bandarbeyla
# Processing Record 19 of Set 4 | manta
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | tucurui
# Processing Record 22 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | vestmannaeyjar
# Processing Record 25 of Set 4 | bluffton
# Processing Record 26 of Set 4 | manga
# Processing Record 27 of Set 4 | ballina
# Processing Record 28 of Set 4 | nanortalik
# Processing Record 29 of Set 4 | aflao
# Processing Record 30 of Set 4 | araouane
# Processing Record 31 of Set 4 | derzhavinsk
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | havre-saint-pierre
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 36 of Set 4 | fort nelson
# Processing Record 37 of Set 4 | hualmay
# Processing Record 38 of Set 4 | lahij
# Processing Record 39 of Set 4 | bezenchuk
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | nago
# Processing Record 42 of Set 4 | mayna
# Processing Record 43 of Set 4 | mananara
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | saint-pierre
# Processing Record 47 of Set 4 | sola
# Processing Record 48 of Set 4 | mayumba
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 5 | kotovo
# Processing Record 2 of Set 5 | maningrida
# Processing Record 3 of Set 5 | karratha
# Processing Record 4 of Set 5 | hambantota
# Processing Record 5 of Set 5 | verkhniy landekh
# Processing Record 6 of Set 5 | sinaloa
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | kyzyl-suu
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | bridgewater
# Processing Record 11 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 5 | ust-omchug
# Processing Record 13 of Set 5 | mwene-ditu
# Processing Record 14 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | korla
# Processing Record 17 of Set 5 | borogontsy
# Processing Record 18 of Set 5 | chumikan
# Processing Record 19 of Set 5 | buala
# Processing Record 20 of Set 5 | soyo
# Processing Record 21 of Set 5 | mirador
# Processing Record 22 of Set 5 | ciudad bolivar
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | ostrovnoy
# Processing Record 29 of Set 5 | taoudenni
# Processing Record 30 of Set 5 | trinidad
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 5 | katherine
# Processing Record 34 of Set 5 | cartagena
# Processing Record 35 of Set 5 | aklavik
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | daru
# Processing Record 38 of Set 5 | ordzhonikidze
# Processing Record 39 of Set 5 | owo
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | mangan
# Processing Record 42 of Set 5 | ugoofaaru
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | prince rupert
# Processing Record 45 of Set 5 | beringovskiy
# Processing Record 46 of Set 5 | qabis
# City not found. Skipping...
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 49 of Set 5 | beloha
# Processing Record 50 of Set 5 | ridgecrest
# Processing Record 1 of Set 6 | fevik
# Processing Record 2 of Set 6 | port-cartier
# Processing Record 3 of Set 6 | namatanai
# Processing Record 4 of Set 6 | tanshui
# City not found. Skipping...
# Processing Record 5 of Set 6 | damietta
# Processing Record 6 of Set 6 | kollam
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | cockburn town
# Processing Record 9 of Set 6 | banda aceh
# Processing Record 10 of Set 6 | santa isabel do rio negro
# Processing Record 11 of Set 6 | kavieng
# Processing Record 12 of Set 6 | pangnirtung
# Processing Record 13 of Set 6 | bambous virieux
# Processing Record 14 of Set 6 | airai
# Processing Record 15 of Set 6 | byron bay
# Processing Record 16 of Set 6 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | ndele
# Processing Record 20 of Set 6 | mabaruma
# Processing Record 21 of Set 6 | alto araguaia
# Processing Record 22 of Set 6 | rantauprapat
# Processing Record 23 of Set 6 | jojoima
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | lazaro cardenas
# Processing Record 26 of Set 6 | hatta
# Processing Record 27 of Set 6 | sol-iletsk
# Processing Record 28 of Set 6 | tchibanga
# Processing Record 29 of Set 6 | verkhoyansk
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | iranshahr
# Processing Record 32 of Set 6 | mountmellick
# Processing Record 33 of Set 6 | gusau
# Processing Record 34 of Set 6 | zhangjiakou
# Processing Record 35 of Set 6 | mersing
# Processing Record 36 of Set 6 | bukavu
# Processing Record 37 of Set 6 | rabat
# Processing Record 38 of Set 6 | hasaki
# Processing Record 39 of Set 6 | hope
# Processing Record 40 of Set 6 | terrak
# Processing Record 41 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | trincomalee
# Processing Record 44 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 6 | abnub
# Processing Record 46 of Set 6 | naples
# Processing Record 47 of Set 6 | okhotsk
# Processing Record 48 of Set 6 | ahipara
# Processing Record 49 of Set 6 | singaparna
# Processing Record 50 of Set 6 | kalmunai
# Processing Record 1 of Set 7 | baruun-urt
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | terrace
# Processing Record 4 of Set 7 | chernyshevskiy
# Processing Record 5 of Set 7 | fenton
# Processing Record 6 of Set 7 | las palmas
# Processing Record 7 of Set 7 | brusciano
# Processing Record 8 of Set 7 | sorland
# Processing Record 9 of Set 7 | oranjemund
# Processing Record 10 of Set 7 | forbes
# Processing Record 11 of Set 7 | mahon
# Processing Record 12 of Set 7 | egvekinot
# Processing Record 13 of Set 7 | ojinaga
# Processing Record 14 of Set 7 | san vicente
# Processing Record 15 of Set 7 | melchor de mencos
# Processing Record 16 of Set 7 | jumla
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | elat
# Processing Record 19 of Set 7 | rosarito
# Processing Record 20 of Set 7 | shihezi
# Processing Record 21 of Set 7 | fare
# Processing Record 22 of Set 7 | vanimo
# Processing Record 23 of Set 7 | porto belo
# Processing Record 24 of Set 7 | filadelfia
# Processing Record 25 of Set 7 | zverinogolovskoye
# Processing Record 26 of Set 7 | azul
# Processing Record 27 of Set 7 | pitimbu
# Processing Record 28 of Set 7 | matagami
# Processing Record 29 of Set 7 | shaoyang
# Processing Record 30 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 7 | buchanan
# Processing Record 32 of Set 7 | netivot
# Processing Record 33 of Set 7 | inuvik
# Processing Record 34 of Set 7 | barcelona
# Processing Record 35 of Set 7 | tuxpan
# Processing Record 36 of Set 7 | santarem
# Processing Record 37 of Set 7 | kestel
# Processing Record 38 of Set 7 | port hedland
# Processing Record 39 of Set 7 | benjamin aceval
# Processing Record 40 of Set 7 | tasiilaq
# Processing Record 41 of Set 7 | pilar
# Processing Record 42 of Set 7 | berdigestyakh
# Processing Record 43 of Set 7 | pundaguitan
# Processing Record 44 of Set 7 | yabrud
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | labuhan
# Processing Record 48 of Set 7 | anadyr
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | gerash
# Processing Record 1 of Set 8 | anloga
# Processing Record 2 of Set 8 | timra
# Processing Record 3 of Set 8 | parry sound
# Processing Record 4 of Set 8 | iqaluit
# Processing Record 5 of Set 8 | manakara
# Processing Record 6 of Set 8 | shubarkuduk
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | ormond beach
# Processing Record 10 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | hofn
# Processing Record 13 of Set 8 | pankovka
# Processing Record 14 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 8 | batagay-alyta
# Processing Record 16 of Set 8 | kamina
# Processing Record 17 of Set 8 | kaitangata
# Processing Record 18 of Set 8 | victor harbor
# Processing Record 19 of Set 8 | troitsko-pechorsk
# Processing Record 20 of Set 8 | krasnovishersk
# Processing Record 21 of Set 8 | laurel
# Processing Record 22 of Set 8 | yenagoa
# Processing Record 23 of Set 8 | la palma
# Processing Record 24 of Set 8 | mahibadhoo
# Processing Record 25 of Set 8 | todos santos
# Processing Record 26 of Set 8 | acapulco
# Processing Record 27 of Set 8 | waingapu
# Processing Record 28 of Set 8 | hanmer springs
# Processing Record 29 of Set 8 | mkushi
# Processing Record 30 of Set 8 | staroderevyankovskaya
# Processing Record 31 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 8 | san matias
# Processing Record 33 of Set 8 | rio gallegos
# Processing Record 34 of Set 8 | kudahuvadhoo
# Processing Record 35 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 8 | alofi
# Processing Record 37 of Set 8 | sakakah
# Processing Record 38 of Set 8 | panjab
# Processing Record 39 of Set 8 | muravlenko
# Processing Record 40 of Set 8 | middle island
# Processing Record 41 of Set 8 | reoti
# Processing Record 42 of Set 8 | falam
# Processing Record 43 of Set 8 | cape canaveral
# Processing Record 44 of Set 8 | jasper
# Processing Record 45 of Set 8 | bara
# Processing Record 46 of Set 8 | mao
# Processing Record 47 of Set 8 | roma
# Processing Record 48 of Set 8 | loreto
# Processing Record 49 of Set 8 | mount gambier
# Processing Record 50 of Set 8 | dombas
# Processing Record 1 of Set 9 | college
# Processing Record 2 of Set 9 | kathu
# Processing Record 3 of Set 9 | kirakira
# Processing Record 4 of Set 9 | necochea
# Processing Record 5 of Set 9 | medicine hat
# Processing Record 6 of Set 9 | korb
# Processing Record 7 of Set 9 | raga
# Processing Record 8 of Set 9 | meulaboh
# Processing Record 9 of Set 9 | trat
# Processing Record 10 of Set 9 | kuhdasht
# Processing Record 11 of Set 9 | joaima
# Processing Record 12 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 9 | bradford
# Processing Record 14 of Set 9 | anshun
# Processing Record 15 of Set 9 | orocue
# Processing Record 16 of Set 9 | wawa
# Processing Record 17 of Set 9 | huanren
# Processing Record 18 of Set 9 | san juan de los morros
# Processing Record 19 of Set 9 | torbay
# Processing Record 20 of Set 9 | mount isa
# Processing Record 21 of Set 9 | cubara
# Processing Record 22 of Set 9 | ketchikan
# Processing Record 23 of Set 9 | dingle
# Processing Record 24 of Set 9 | yarim
# Processing Record 25 of Set 9 | tambopata
# Processing Record 26 of Set 9 | los llanos de aridane
# Processing Record 27 of Set 9 | fenoarivo atsinanana
# Processing Record 28 of Set 9 | madimba
# Processing Record 29 of Set 9 | teknaf
# Processing Record 30 of Set 9 | cap estate
# Processing Record 31 of Set 9 | flin flon
# Processing Record 32 of Set 9 | imbituba
# Processing Record 33 of Set 9 | carauari
# Processing Record 34 of Set 9 | north bend
# Processing Record 35 of Set 9 | rochester
# Processing Record 36 of Set 9 | hit
# Processing Record 37 of Set 9 | jinchang
# Processing Record 38 of Set 9 | logansport
# Processing Record 39 of Set 9 | pokaran
# Processing Record 40 of Set 9 | kidal
# Processing Record 41 of Set 9 | khasan
# Processing Record 42 of Set 9 | monteagudo
# Processing Record 43 of Set 9 | nettuno
# Processing Record 44 of Set 9 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 45 of Set 9 | daugavpils
# Processing Record 46 of Set 9 | miles city
# Processing Record 47 of Set 9 | camacha
# Processing Record 48 of Set 9 | bardiyah
# Processing Record 49 of Set 9 | sitka
# Processing Record 50 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 10 | tlahualilo
# City not found. Skipping...
# Processing Record 2 of Set 10 | duku
# Processing Record 3 of Set 10 | tual
# Processing Record 4 of Set 10 | angoche
# Processing Record 5 of Set 10 | moussoro
# Processing Record 6 of Set 10 | ossora
# Processing Record 7 of Set 10 | omboue
# Processing Record 8 of Set 10 | kudat
# Processing Record 9 of Set 10 | letterkenny
# Processing Record 10 of Set 10 | porto velho
# Processing Record 11 of Set 10 | brae
# Processing Record 12 of Set 10 | ponta delgada
# Processing Record 13 of Set 10 | lorengau
# Processing Record 14 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 10 | chandrakona
# Processing Record 16 of Set 10 | kutum
# Processing Record 17 of Set 10 | grindavik
# Processing Record 18 of Set 10 | angren
# Processing Record 19 of Set 10 | mackay
# Processing Record 20 of Set 10 | tall kayf
# Processing Record 21 of Set 10 | biak
# Processing Record 22 of Set 10 | kushmurun
# Processing Record 23 of Set 10 | takaungu
# Processing Record 24 of Set 10 | paamiut
# Processing Record 25 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 10 | touros
# Processing Record 27 of Set 10 | ust-nera
# Processing Record 28 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 10 | vestmanna
# Processing Record 30 of Set 10 | atambua
# Processing Record 31 of Set 10 | chimbote
# Processing Record 32 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 10 | arbagar
# Processing Record 34 of Set 10 | polovinnoye
# Processing Record 35 of Set 10 | waipawa
# Processing Record 36 of Set 10 | sangmelima
# Processing Record 37 of Set 10 | yelizovo
# Processing Record 38 of Set 10 | rincon
# Processing Record 39 of Set 10 | kamyshevatskaya
# Processing Record 40 of Set 10 | kingman
# Processing Record 41 of Set 10 | gornozavodsk
# Processing Record 42 of Set 10 | tallahassee
# Processing Record 43 of Set 10 | bo rai
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | medea
# Processing Record 46 of Set 10 | pareora
# Processing Record 47 of Set 10 | lincoln
# Processing Record 48 of Set 10 | mandera
# Processing Record 49 of Set 10 | raudeberg
# Processing Record 50 of Set 10 | terney
# Processing Record 1 of Set 11 | uribia
# Processing Record 2 of Set 11 | moose factory
# Processing Record 3 of Set 11 | boende
# Processing Record 4 of Set 11 | sur
# Processing Record 5 of Set 11 | novyy urengoy
# Processing Record 6 of Set 11 | venado tuerto
# Processing Record 7 of Set 11 | lavumisa
# Processing Record 8 of Set 11 | ngorongoro
# Processing Record 9 of Set 11 | uitenhage
# Processing Record 10 of Set 11 | markova
# Processing Record 11 of Set 11 | deputatskiy
# Processing Record 12 of Set 11 | smithers
# Processing Record 13 of Set 11 | duz
# City not found. Skipping...
# Processing Record 14 of Set 11 | vikulovo
# Processing Record 15 of Set 11 | farah
# Processing Record 16 of Set 11 | mongoumba
# Processing Record 17 of Set 11 | micheweni
# Processing Record 18 of Set 11 | grand-santi
# Processing Record 19 of Set 11 | tiznit
# Processing Record 20 of Set 11 | komsomolskiy
# Processing Record 21 of Set 11 | taguatinga
# Processing Record 22 of Set 11 | sibolga
# Processing Record 23 of Set 11 | morro bay
# Processing Record 24 of Set 11 | chapais
# Processing Record 25 of Set 11 | camopi
# Processing Record 26 of Set 11 | mecca
# Processing Record 27 of Set 11 | tighina
# Processing Record 28 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 29 of Set 11 | jishou
# Processing Record 30 of Set 11 | carutapera
# Processing Record 31 of Set 11 | winfield
# Processing Record 32 of Set 11 | de-kastri
# Processing Record 33 of Set 11 | samarai
# Processing Record 34 of Set 11 | sinjah
# City not found. Skipping...
# Processing Record 35 of Set 11 | koulamoutou
# Processing Record 36 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 11 | hebertville
# City not found. Skipping...
# Processing Record 38 of Set 11 | morant bay
# Processing Record 39 of Set 11 | malino
# Processing Record 40 of Set 11 | palasa
# Processing Record 41 of Set 11 | oussouye
# Processing Record 42 of Set 11 | ventersburg
# Processing Record 43 of Set 11 | george town
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | hendek
# Processing Record 46 of Set 11 | itarsi
# Processing Record 47 of Set 11 | broken hill
# Processing Record 48 of Set 11 | shillong
# Processing Record 49 of Set 11 | salalah
# Processing Record 50 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 1 of Set 12 | huarmey
# Processing Record 2 of Set 12 | caceres
# Processing Record 3 of Set 12 | mayo
# Processing Record 4 of Set 12 | veseloyarsk
# Processing Record 5 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 12 | tadine
# Processing Record 7 of Set 12 | dukat
# Processing Record 8 of Set 12 | ullapool
# Processing Record 9 of Set 12 | baghdad
# Processing Record 10 of Set 12 | alta
# Processing Record 11 of Set 12 | axim
# Processing Record 12 of Set 12 | vrangel
# Processing Record 13 of Set 12 | moree
# Processing Record 14 of Set 12 | ayr
# Processing Record 15 of Set 12 | bonthe
# Processing Record 16 of Set 12 | bloemfontein
# Processing Record 17 of Set 12 | port-gentil
# Processing Record 18 of Set 12 | gornyy
# Processing Record 19 of Set 12 | yuzhne
# Processing Record 20 of Set 12 | fort dodge
# Processing Record 21 of Set 12 | verkhneuralsk
# Processing Record 22 of Set 12 | albury
# Processing Record 23 of Set 12 | zatoka
# Processing Record 24 of Set 12 | bow island
# Processing Record 25 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 12 | mareeba
# Processing Record 27 of Set 12 | laiyang
# Processing Record 28 of Set 12 | ankazoabo
# Processing Record 29 of Set 12 | margate
# Processing Record 30 of Set 12 | tabou
# Processing Record 31 of Set 12 | port macquarie
# Processing Record 32 of Set 12 | chipinge
# Processing Record 33 of Set 12 | jacmel
# Processing Record 34 of Set 12 | harper
# Processing Record 35 of Set 12 | ostashkov
# Processing Record 36 of Set 12 | rio grande
# Processing Record 37 of Set 12 | ypsilanti
# Processing Record 38 of Set 12 | nishihara
# Processing Record 39 of Set 12 | bilma
# Processing Record 40 of Set 12 | almirante
# Processing Record 41 of Set 12 | vao
# Processing Record 42 of Set 12 | sioux lookout
# Processing Record 43 of Set 12 | ignacio de la llave
# Processing Record 44 of Set 12 | khatanga
# Processing Record 45 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 12 | majene
# Processing Record 47 of Set 12 | koboko
# Processing Record 48 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 12 | tambun
# Processing Record 1 of Set 13 | taber
# Processing Record 2 of Set 13 | goundam
# Processing Record 3 of Set 13 | eucaliptus
# Processing Record 4 of Set 13 | anori
# Processing Record 5 of Set 13 | saint-augustin
# Processing Record 6 of Set 13 | cordoba
# Processing Record 7 of Set 13 | cartagena del chaira
# Processing Record 8 of Set 13 | new port richey
# Processing Record 9 of Set 13 | ishinomaki
# Processing Record 10 of Set 13 | loubomo
# Processing Record 11 of Set 13 | kulim
# Processing Record 12 of Set 13 | khudumelapye
# Processing Record 13 of Set 13 | olafsvik
# Processing Record 14 of Set 13 | frontera
# Processing Record 15 of Set 13 | kangaatsiaq
# Processing Record 16 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 13 | omsukchan
# Processing Record 18 of Set 13 | mehamn
# Processing Record 19 of Set 13 | pauini
# Processing Record 20 of Set 13 | mezhdurechensk
# Processing Record 21 of Set 13 | maridi
# Processing Record 22 of Set 13 | rokiskis
# Processing Record 23 of Set 13 | lososina
# Processing Record 24 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 13 | kajaani
# Processing Record 26 of Set 13 | valdivia
# Processing Record 27 of Set 13 | martapura
# Processing Record 28 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 13 | maymyo
# Processing Record 30 of Set 13 | manokwari
# Processing Record 31 of Set 13 | monrovia
# Processing Record 32 of Set 13 | wanning
# Processing Record 33 of Set 13 | yulara
# Processing Record 34 of Set 13 | san fernando
# Processing Record 35 of Set 13 | endicott
# Processing Record 36 of Set 13 | aykhal
# Processing Record 37 of Set 13 | plettenberg bay
# Processing Record 38 of Set 13 | krasnoborsk
# Processing Record 39 of Set 13 | marfino
# Processing Record 40 of Set 13 | pokhara
# Processing Record 41 of Set 13 | los banos
# Processing Record 42 of Set 13 | stephenville
# Processing Record 43 of Set 13 | marawi
# Processing Record 44 of Set 13 | poretskoye
# Processing Record 45 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 13 | oistins
# Processing Record 47 of Set 13 | ustyuzhna
# Processing Record 48 of Set 13 | oksfjord
# Processing Record 49 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 50 of Set 13 | zubova polyana
# Processing Record 1 of Set 14 | hervey bay
# Processing Record 2 of Set 14 | boguchany
# Processing Record 3 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 4 of Set 14 | zhigansk
# Processing Record 5 of Set 14 | sao joao da barra
# Processing Record 6 of Set 14 | oga
# Processing Record 7 of Set 14 | caconda
# Processing Record 8 of Set 14 | wamba
# Processing Record 9 of Set 14 | akdepe
# Processing Record 10 of Set 14 | rio bueno
# Processing Record 11 of Set 14 | kloulklubed
# Processing Record 12 of Set 14 | janfida
# Processing Record 13 of Set 14 | nuuk
# Processing Record 14 of Set 14 | umea
# Processing Record 15 of Set 14 | iskateley
# Processing Record 16 of Set 14 | vuktyl
# Processing Record 17 of Set 14 | turki
# Processing Record 18 of Set 14 | gimli
# Processing Record 19 of Set 14 | nhulunbuy
# Processing Record 20 of Set 14 | namtsy
# Processing Record 21 of Set 14 | wana
# Processing Record 22 of Set 14 | bela
# Processing Record 23 of Set 14 | hovd
# Processing Record 24 of Set 14 | tilichiki
# Processing Record 25 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 14 | gizo
# Processing Record 28 of Set 14 | isla vista
# Processing Record 29 of Set 14 | pemangkat
# Processing Record 30 of Set 14 | abu dhabi
# Processing Record 31 of Set 14 | trairi
# Processing Record 32 of Set 14 | eureka
# Processing Record 33 of Set 14 | tecate
# Processing Record 34 of Set 14 | verkhniy avzyan
# Processing Record 35 of Set 14 | tolentino
# Processing Record 36 of Set 14 | xuddur
# Processing Record 37 of Set 14 | herat
# Processing Record 38 of Set 14 | quelimane
# Processing Record 39 of Set 14 | wenling
# Processing Record 40 of Set 14 | erzin
# Processing Record 41 of Set 14 | priiskovyy
# Processing Record 42 of Set 14 | smidovich
# Processing Record 43 of Set 14 | mianyang
# Processing Record 44 of Set 14 | port keats
# Processing Record 45 of Set 14 | angra
# City not found. Skipping...
# Processing Record 46 of Set 14 | opuwo
# Processing Record 47 of Set 14 | escanaba
# Processing Record 48 of Set 14 | patacamaya
# Processing Record 49 of Set 14 | husavik
# Processing Record 50 of Set 14 | huzhou
# Processing Record 1 of Set 15 | zdvinsk
# Processing Record 2 of Set 15 | makat
# Processing Record 3 of Set 15 | dondo
# Processing Record 4 of Set 15 | kieta
# Processing Record 5 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 6 of Set 15 | stokmarknes
# Processing Record 7 of Set 15 | gladstone
# Processing Record 8 of Set 15 | cerrito
# Processing Record 9 of Set 15 | huai thalaeng
# Processing Record 10 of Set 15 | kifri
# Processing Record 11 of Set 15 | kiruna
# Processing Record 12 of Set 15 | chara
# Processing Record 13 of Set 15 | hanna
# Processing Record 14 of Set 15 | waldoboro
# Processing Record 15 of Set 15 | sinnamary
# Processing Record 16 of Set 15 | port hawkesbury
# Processing Record 17 of Set 15 | hangu
# Processing Record 18 of Set 15 | bubaque
# Processing Record 19 of Set 15 | westport
# Processing Record 20 of Set 15 | chum phae
# Processing Record 21 of Set 15 | honningsvag
# Processing Record 22 of Set 15 | mitsamiouli
# Processing Record 23 of Set 15 | srednekolymsk
# Processing Record 24 of Set 15 | kesennuma
# City not found. Skipping...
# Processing Record 25 of Set 15 | chervonohryhorivka
# Processing Record 26 of Set 15 | tarkwa
# Processing Record 27 of Set 15 | kozmodemyansk
# Processing Record 28 of Set 15 | konya
# Processing Record 29 of Set 15 | bluefields
# Processing Record 30 of Set 15 | izumo
# Processing Record 31 of Set 15 | luebo
# Processing Record 32 of Set 15 | olinda
# Processing Record 33 of Set 15 | limot
# Processing Record 34 of Set 15 | comodoro rivadavia
# Processing Record 35 of Set 15 | huanta
# Processing Record 36 of Set 15 | sheksna
# Processing Record 37 of Set 15 | ostersund
# Processing Record 38 of Set 15 | chicama
# Processing Record 39 of Set 15 | galle
# Processing Record 40 of Set 15 | sabang
# Processing Record 41 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 43 of Set 15 | coihueco
# Processing Record 44 of Set 15 | kaduqli
# Processing Record 45 of Set 15 | aswan
# Processing Record 46 of Set 15 | hamilton
# Processing Record 47 of Set 15 | sept-iles
# Processing Record 48 of Set 15 | mackenzie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
#Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Policarpo  12.1791  125.5072     83.30        74          98
# 1     Bredasdorp -34.5322   20.0403     61.36        81           6
# 2     Butaritari   3.0707  172.7902     81.39        73          75
# 3    Hot Springs  34.5037  -93.0552     72.00        23           0
# 4       Pochutla  15.7432  -96.4661     81.82        77         100
# 5    Provideniya  64.3833 -173.3000     22.86        73          99
# 6    East London -33.0153   27.9116     66.92        87          97
# 7        Qaanaaq  77.4840  -69.3632     -3.51        97         100
# 8        Aksarka  66.5606   67.7975     -4.74        97          99
# 9         Dikson  73.5069   80.5464     -9.69       100          81
#
#    Wind Speed Country Current Description                 Date
# 0       11.68      PH     overcast clouds  2022-03-27 00:48:42
# 1        8.52      ZA           clear sky  2022-03-27 00:48:42
# 2       14.61      KI       broken clouds  2022-03-27 00:48:43
# 3        4.61      US           clear sky  2022-03-27 00:44:05
# 4        5.10      MX     overcast clouds  2022-03-27 00:48:43
# 5        1.21      RU     overcast clouds  2022-03-27 00:48:44
# 6        8.63      ZA          light rain  2022-03-27 00:47:06
# 7        3.71      GL     overcast clouds  2022-03-27 00:48:44
# 8        7.76      RU     overcast clouds  2022-03-27 00:48:45
# 9       12.21      RU       broken clouds  2022-03-27 00:48:45

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    San Policarpo      PH  12.1791  125.5072     83.30        74          98
# 1       Bredasdorp      ZA -34.5322   20.0403     61.36        81           6
# 2       Butaritari      KI   3.0707  172.7902     81.39        73          75
# 3      Hot Springs      US  34.5037  -93.0552     72.00        23           0
# 4         Pochutla      MX  15.7432  -96.4661     81.82        77         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 674        Kaduqli      SD  11.0167   29.7167     73.36        10          80
# 675          Aswan      EG  24.0934   32.9070     56.50        24           0
# 676       Hamilton      US  39.1834  -84.5333     34.43        64          29
# 677      Sept-Iles      CA  50.2001  -66.3821     31.05        96         100
# 678      Mackenzie      CA  55.2999 -123.1698     41.22        38          75
#
#      Wind Speed Current Description
# 0         11.68     overcast clouds
# 1          8.52           clear sky
# 2         14.61       broken clouds
# 3          4.61           clear sky
# 4          5.10     overcast clouds
# ..          ...                 ...
# 674       13.56       broken clouds
# 675        4.61           clear sky
# 676        7.00    scattered clouds
# 677        9.22                mist
# 678        0.00       broken clouds
#
# [679 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
